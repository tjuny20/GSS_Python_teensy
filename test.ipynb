# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(2*np.arange(10), np.random.rand(10))

# %%
import matplotlib as mpl
import matplotlib as mpl

print(mpl.get_configdir())
print(mpl.rcParams["font.size"])
print(mpl.rcParams["axes.prop_cycle"])
print(mpl.rcParams["axes.linewidth"])
# Out:
# /Users/ton/.matplotlib
# 12.0
# cycler('color', ['#4c69a8', '#f0724f', '#9e9e7e', '#c6abd4', '#212121'])
# 1.0

# %%
a = plt.get_cmap()

# %%
plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# ['#4c69a8', '#f0724f', '#9e9e7e', '#c6abd4', '#212121']
